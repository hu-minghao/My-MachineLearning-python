# %%
from sklearn.datasets import load_wine
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import matplotlib.pyplot as plt

# %%
wine=load_wine()
x,y=wine.data,wine.target
pca=PCA(n_components=2)
pca.fit(x)
#输出转化后的数据
pca_x=pca.transform(x)
#输出方差百分比及方差
print(pca.explained_variance_ratio_)
print(pca.explained_variance_)
plt.title('wine PCA')
plt.scatter(pca_x[:,0],pca_x[:,1],marker='o',c=y)
plt.xlabel('pca feature1')
plt.ylabel('pca feature2')
plt.show()
# Out:
# [0.99809123 0.00173592]
# [99201.78951748   172.53526648]

# %%
#选定lda将维后特征个数
lda=LinearDiscriminantAnalysis(n_components=2)
#线性判例分析为监督训练
lda.fit(x,y)
#转化后的数据
lda_x=lda.transform(x)
plt.title('wine LDA')
plt.scatter(lda_x[:,0],lda_x[:,1],marker='o',c=y)
plt.xlabel('LDA feature1')
plt.ylabel('LDA feature2')
plt.show()
